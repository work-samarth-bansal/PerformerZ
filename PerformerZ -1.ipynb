# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
dataf = pd.read_csv("C:/Users/samar/OneDrive/Desktop/Data Science/PerformerZ/HR_comma_sep.csv")
dataf
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dataf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
dataf.describe
# Out:
# <bound method NDFrame.describe of        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
dataf.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
dataf.shape
# Out:
# (14999, 10)

# %%
dataf.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
print("Total Null/Empty entry in Dataset is "+str(dataf.isnull().sum().sum()))
# Out:
# Total Null/Empty entry in Dataset is 0

# %%
df = dataf.copy()

df = df.drop(['sales'],axis=1)
df = df.drop(['salary'],axis=1)

df.corr()
# Out:
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
#                        average_montly_hours  time_spend_company  \
# satisfaction_level                -0.020048           -0.100866
# last_evaluation                    0.339742            0.131591
# number_project                     0.417211            0.196786
# ...

# %%
correlation = df.corr()  
correlation.style.background_gradient(cmap = 'BrBG')
# Out:
# <style type="text/css">
# #T_f4697_row0_col0, #T_f4697_row1_col1, #T_f4697_row2_col2, #T_f4697_row3_col3, #T_f4697_row4_col4, #T_f4697_row5_col5, #T_f4697_row6_col6, #T_f4697_row7_col7 {
#   background-color: #003c30;
#   color: #f1f1f1;
# }
# #T_f4697_row0_col1 {
#   background-color: #91560d;
#   color: #f1f1f1;
# }
# #T_f4697_row0_col2, #T_f4697_row0_col3, #T_f4697_row0_col4, #T_f4697_row0_col6, #T_f4697_row5_col1, #T_f4697_row6_col0, #T_f4697_row6_col5, #T_f4697_row6_col7, #T_f4697_row7_col1 {
#   background-color: #543005;
#   color: #f1f1f1;
# }
# #T_f4697_row0_col5 {
#   background-color: #b77928;
#   color: #f1f1f1;
# }
# #T_f4697_row0_col7 {
#   background-color: #824b09;
#   color: #f1f1f1;
# }
# #T_f4697_row1_col0, #T_f4697_row1_col3, #T_f4697_row2_col1 {
#   background-color: #ebd6a2;
#   color: #000000;
# }
# #T_f4697_row1_col2 {
#   background-color: #f6ecd3;
#   color: #000000;
# }
# #T_f4697_row1_col4 {
#   background-color: #c38936;
#   color: #f1f1f1;
# }
# ...

# %%
seaborn.set_theme(style="darkgrid")
seaborn.heatmap(correlation)
# Out:
# <Axes: >

# %%
satisfaction_level_corr = correlation["satisfaction_level"].drop("satisfaction_level")
corr1 = satisfaction_level_corr.sort_values(ascending=False)
print(corr1)
# Out:
# last_evaluation          0.105021
# Work_accident            0.058697
# promotion_last_5years    0.025605
# average_montly_hours    -0.020048
# time_spend_company      -0.100866
# number_project          -0.142970
# left                    -0.388375
# Name: satisfaction_level, dtype: float64

# %%
last_evaluation_corr = correlation["last_evaluation"].drop("last_evaluation")
corr2 = last_evaluation_corr.sort_values(ascending=False)
print(corr2)
# Out:
# number_project           0.349333
# average_montly_hours     0.339742
# time_spend_company       0.131591
# satisfaction_level       0.105021
# left                     0.006567
# Work_accident           -0.007104
# promotion_last_5years   -0.008684
# Name: last_evaluation, dtype: float64

# %%
left_corr = correlation["left"].drop("left")
corr3 = left_corr.sort_values(ascending=False)
print(corr3)
# Out:
# time_spend_company       0.144822
# average_montly_hours     0.071287
# number_project           0.023787
# last_evaluation          0.006567
# promotion_last_5years   -0.061788
# Work_accident           -0.154622
# satisfaction_level      -0.388375
# Name: left, dtype: float64

# %%
promotion_last_5years_corr = correlation["promotion_last_5years"].drop("promotion_last_5years")
corr4 = promotion_last_5years_corr.sort_values(ascending=False)
print(corr4)
# Out:
# time_spend_company      0.067433
# Work_accident           0.039245
# satisfaction_level      0.025605
# average_montly_hours   -0.003544
# number_project         -0.006064
# last_evaluation        -0.008684
# left                   -0.061788
# Name: promotion_last_5years, dtype: float64

# %% [markdown]
# # Left

# %%
left_corr = correlation["left"].drop("left")
corr3 = left_corr.sort_values(ascending=False)
print(corr3)
# Out:
# time_spend_company       0.144822
# average_montly_hours     0.071287
# number_project           0.023787
# last_evaluation          0.006567
# promotion_last_5years   -0.061788
# Work_accident           -0.154622
# satisfaction_level      -0.388375
# Name: left, dtype: float64

# %%
seaborn.lineplot(y=df['left'],x=df['time_spend_company'], data=df)
# Out:
# <Axes: xlabel='time_spend_company', ylabel='left'>

# %%
df[df['time_spend_company']>=7]['left'].value_counts()
# Out:
# 0    564
# Name: left, dtype: int64

# %%
df[df['time_spend_company']==5]['left'].value_counts()
# Out:
# 1    833
# 0    640
# Name: left, dtype: int64

# %%
seaborn.lineplot(y=df['left'],x=df['average_montly_hours'], data=df)
# Out:
# <Axes: xlabel='average_montly_hours', ylabel='left'>

# %%
df[df['average_montly_hours']>280]
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 11                   0.11             0.81               6
# 20                   0.11             0.83               6
# 22                   0.09             0.95               6
# 30                   0.09             0.62               6
# 38                   0.11             0.89               6
# ...                   ...              ...             ...
# 14950                0.39             0.68               2
# 14972                0.11             0.97               6
# 14975                0.10             0.79               7
# 14979                0.09             0.93               6
# 14993                0.76             0.83               6
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 11                      305                   4              0     1
# 20                      282                   4              0     1
# ...

# %%
seaborn.lineplot(y=df['left'],x=df['number_project'], data=df)
# Out:
# <Axes: xlabel='number_project', ylabel='left'>

# %%
df[df['number_project']==7]['left'].value_counts()
# Out:
# 1    256
# Name: left, dtype: int64

# %%
seaborn.lineplot(y=df['left'],x=df['last_evaluation'], data=df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='left'>

# %%
df[df['last_evaluation']==.46]['left'].value_counts()
# Out:
# 1    162
# 0     49
# Name: left, dtype: int64

# %%
left_count = seaborn.countplot(x='left',data=df)

for bars in left_count.containers:
    left_count.bar_label(bars)

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years'],
#       dtype='object')

# %%
selected_columns = ["satisfaction_level", "last_evaluation", "number_project", "average_montly_hours", "time_spend_company"]
seaborn.pairplot(dataf[selected_columns], kind='scatter', diag_kind='kde')

# %%
seaborn.histplot(data=dataf, x="left", kde=True)
# Out:
# <Axes: xlabel='left', ylabel='Count'>

# %%
df['promotion_last_5years'].value_counts()
# Out:
# 0    14680
# 1      319
# Name: promotion_last_5years, dtype: int64

# %%
df['satisfaction_level'].value_counts()
# Out:
# 0.10    358
# 0.11    335
# 0.74    257
# 0.77    252
# 0.84    247
#        ...
# 0.25     34
# 0.28     31
# 0.27     30
# 0.26     30
# 0.12     30
# Name: satisfaction_level, Length: 92, dtype: int64

# %%
department_turnover = dataf.groupby('sales')['left'].mean()

plt.figure(figsize=(10, 6))
department_turnover.plot(kind='bar', color='skyblue')
plt.title('Exit Rate by Department')
plt.xlabel('Department')
plt.ylabel('Exit Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
salary_turnover = dataf.groupby('salary')['left'].mean()

# Create a bar chart to visualize the turnover rate by salary level
plt.figure(figsize=(8, 5))
salary_turnover.plot(kind='bar', color='salmon')
plt.title('Exit Rate by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Exit Rate')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
from scipy import stats

# %%
left_group = dataf[dataf['left'] == 1]['satisfaction_level']
not_left_group = dataf[dataf['left'] == 0]['satisfaction_level']

# Perform a two-sample t-test
t_stat, p_value = stats.ttest_ind(left_group, not_left_group, equal_var=False)

# Define a significance level (alpha)
alpha = 0.05

# Check the p-value against the significance level
if p_value < alpha:
    print(f"Reject the null hypothesis. There is a statistically significant difference in satisfaction levels between employees who left and those who didn't.")
else:
    print("Fail to reject the null hypothesis. There is no statistically significant difference in satisfaction levels between the two groups.")
# Out:
# Reject the null hypothesis. There is a statistically significant difference in satisfaction levels between employees who left and those who didn't.
