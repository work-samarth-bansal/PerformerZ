# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme(style="whitegrid")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the dataset

# %%
df= pd.read_csv("C:/Users/samar/OneDrive/Desktop/Data Science/PerformerZ/HR_comma_sep.csv")
df
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  sales  \
# 0                   3              0     1                      0  sales
# 1                   6              0     1                      0  sales
# 2                   4              0     1                      0  sales
# 3                   5              0     1                      0  sales
# 4                   3              0     1                      0  sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# ...

# %%
df.tail()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 14994                   151                   3              0     1
# 14995                   160                   3              0     1
# 14996                   143                   3              0     1
# 14997                   280                   4              0     1
# 14998                   158                   3              0     1
#
#        promotion_last_5years    sales salary
# 14994                      0  support    low
# 14995                      0  support    low
# 14996                      0  support    low
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.info
# Out:
# <bound method DataFrame.info of        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   sales                  14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
df.describe(include = 'object')
# Out:
#         sales salary
# count   14999  14999
# unique     10      3
# top     sales    low
# freq     4140   7316

# %%
for col in df.describe(include = 'object').columns:
    print(col)
    print(df[col].unique())
    print('-'*50)
# Out:
# sales
# ['sales' 'accounting' 'hr' 'technical' 'support' 'management' 'IT'
#  'product_mng' 'marketing' 'RandD']
# --------------------------------------------------
# salary
# ['low' 'medium' 'high']
# --------------------------------------------------

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# sales                    0
# salary                   0
# dtype: int64

# %%
df.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %%
df['average_montly_hours'].plot(kind='box')
# Out:
# <Axes: >

# %%
sat=df['satisfaction_level'].value_counts(normalize = True)
sat
# Out:
# 0.10    0.023868
# 0.11    0.022335
# 0.74    0.017134
# 0.77    0.016801
# 0.84    0.016468
#           ...
# 0.25    0.002267
# 0.28    0.002067
# 0.27    0.002000
# 0.26    0.002000
# 0.12    0.002000
# Name: satisfaction_level, Length: 92, dtype: float64

# %%
sat = df['Work_accident'].value_counts(normalize=True)
plt.figure(figsize=(5, 4))
plt.title('Work_accident level of employees')
plt.bar(sat.index, sat.values, edgecolor='k', width=0.7)
plt.xticks(sat.index, ['Accident', 'Safe'])
plt.show()

# %%
sat
# Out:
# 0    0.85539
# 1    0.14461
# Name: Work_accident, dtype: float64

# %%
sat = df['left'].value_counts(normalize=True)
plt.figure(figsize=(5, 4))
plt.title('Leaving and Staying Ratio')
plt.bar(sat.index, sat.values, edgecolor='k', width=0.7)
plt.xticks(sat.index, ['Stayed', 'Left'])
plt.show()

# %%
sat
# Out:
# 0    0.761917
# 1    0.238083
# Name: left, dtype: float64

# %%
sat = df['promotion_last_5years'].value_counts(normalize=True)
plt.figure(figsize=(5, 4))
plt.title('Promotion Status of employees')
plt.bar(sat.index, sat.values, edgecolor='k', width=0.7)
plt.xticks(sat.index, ['Not Promoted', 'Promoted'])
plt.show()

# %%
sat
# Out:
# 0    0.978732
# 1    0.021268
# Name: promotion_last_5years, dtype: float64

# %%
import matplotlib.pyplot as plt
sat = df['satisfaction_level'].value_counts(normalize=True)
plt.figure(figsize=(5, 4))
plt.title('Satisfaction level of employees')
plt.bar(sat.index, sat.values, edgecolor='k', width=0.7)
plt.show()
print(sat)
# Out:
# 0.10    0.023868
# 0.11    0.022335
# 0.74    0.017134
# 0.77    0.016801
# 0.84    0.016468
#           ...
# 0.25    0.002267
# 0.28    0.002067
# 0.27    0.002000
# 0.26    0.002000
# 0.12    0.002000
# Name: satisfaction_level, Length: 92, dtype: float64

# %%
satisfaction_count=pd.DataFrame(df['satisfaction_level'].value_counts())
satisfaction_count
# Out:
#       satisfaction_level
# 0.10                 358
# 0.11                 335
# 0.74                 257
# 0.77                 252
# 0.84                 247
# ...                  ...
# 0.25                  34
# 0.28                  31
# 0.27                  30
# 0.26                  30
# 0.12                  30
#
# [92 rows x 1 columns]

# %%
sal=df['salary'].value_counts(normalize = True)
sal
# Out:
# low       0.487766
# medium    0.429762
# high      0.082472
# Name: salary, dtype: float64

# %%
salary_counts = df['salary'].value_counts()
print(salary_counts)
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
salary_counts = df['salary'].value_counts()
total_employees = len(df)
salary_percentages = (salary_counts / total_employees) * 100
print(salary_percentages)
# Out:
# low       48.776585
# medium    42.976198
# high       8.247216
# Name: salary, dtype: float64

# %%
average_projects = df['number_project'].mean()
print("Average number of projects done by employees:", average_projects)
# Out:
# Average number of projects done by employees: 3.80305353690246

# %%
average_projects = df['number_project'].median()
print("Median of projects done by employees:", average_projects)
# Out:
# Median of projects done by employees: 4.0

# %%
avg_monthly_hours = df['average_montly_hours'].mean()
avg_time_in_company = df['time_spend_company'].mean()
print("Average monthly hours worked by employees:", avg_monthly_hours)
print("Average time spent in the company by employees:", avg_time_in_company)
# Out:
# Average monthly hours worked by employees: 201.0503366891126
# Average time spent in the company by employees: 3.498233215547703

# %%
avg_monthly_hours = df['average_montly_hours'].median()
avg_time_in_company = df['time_spend_company'].median()
print("Median monthly hours worked by employees:", avg_monthly_hours)
print("Median of time spent in the company by employees:", avg_time_in_company)
# Out:
# Median monthly hours worked by employees: 200.0
# Median of time spent in the company by employees: 3.0

# %%
salary_groups = df.groupby('salary')
average_hours_by_salary = salary_groups['average_montly_hours'].mean()
print(average_hours_by_salary)
# Out:
# salary
# high      199.867421
# low       200.996583
# medium    201.338349
# Name: average_montly_hours, dtype: float64

# %%
salary_groups = df.groupby('salary')
average_hours_by_salary = salary_groups['average_montly_hours'].median()
print(average_hours_by_salary)
# Out:
# salary
# high      199.0
# low       199.0
# medium    201.0
# Name: average_montly_hours, dtype: float64

# %% [markdown]
# # Satisfaction_level

# %%
summary_stats = df['satisfaction_level'].describe()
summary_stats
# Out:
# count    14999.000000
# mean         0.612834
# std          0.248631
# min          0.090000
# 25%          0.440000
# 50%          0.640000
# 75%          0.820000
# max          1.000000
# Name: satisfaction_level, dtype: float64

# %%
sns.histplot(df['satisfaction_level'], kde=True)
plt.title('Distribution of Satisfaction Levels')
plt.xlabel('Satisfaction Level')
plt.ylabel('Frequency')
plt.show()

# %%
sns.boxplot(x='salary', y='satisfaction_level', data=df)
plt.title('Satisfaction Level by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Satisfaction Level')
plt.show()

# %%
correlation = df['satisfaction_level'].corr(df['last_evaluation'])
print("Correlation between satisfaction_level and last_evaluation:", correlation)
# Out:
# Correlation between satisfaction_level and last_evaluation: 0.1050212139714851

# %%
left_vs_stayed = df.groupby('left')['satisfaction_level'].mean()
print(left_vs_stayed)
# Out:
# left
# 0    0.666810
# 1    0.440098
# Name: satisfaction_level, dtype: float64

# %%
department_satisfaction = df.groupby('sales')['satisfaction_level'].mean()
department_satisfaction.plot(kind='bar', figsize=(10, 6))
plt.title('Average Satisfaction Level by Department')
plt.xlabel('Department')
plt.ylabel('Average Satisfaction Level')
plt.show()

# %%
salary_satisfaction = df.groupby('salary')['satisfaction_level'].mean()
salary_satisfaction.plot(kind='bar', figsize=(8, 6))
plt.title('Average Satisfaction Level by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Average Satisfaction Level')
plt.show()

# %%
import matplotlib.pyplot as plt
df['satisfaction_level'].hist()
plt.show()

# %%
print(df.corr()['satisfaction_level'])
# Out:
# satisfaction_level       1.000000
# last_evaluation          0.105021
# number_project          -0.142970
# average_montly_hours    -0.020048
# time_spend_company      -0.100866
# Work_accident            0.058697
# left                    -0.388375
# promotion_last_5years    0.025605
# Name: satisfaction_level, dtype: float64

# %%
experience_satisfaction = df.groupby('time_spend_company')['satisfaction_level'].mean()
experience_satisfaction.plot(kind='bar', figsize=(10, 6))
plt.title('Average Satisfaction Level by Years of Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Average Satisfaction Level')
plt.show()

# %%
print(df.columns)
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
numerical_columns = ['satisfaction_level',  'number_project', 'average_montly_hours', ]


correlation_matrix = df[numerical_columns].corr()


plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
promotion_satisfaction = df.groupby('promotion_last_5years')['satisfaction_level'].mean()
promotion_satisfaction.plot(kind='bar', figsize=(8, 6))
plt.title('Average Satisfaction Level by Promotion Status')
plt.xlabel('Promotion Status (0 = No, 1 = Yes)')
plt.ylabel('Average Satisfaction Level')
plt.xticks(rotation=0)
plt.show()

# %%
salary_satisfaction = df.groupby('salary')['satisfaction_level'].mean()
salary_satisfaction.plot(kind='bar', figsize=(8, 6))
plt.title('Average Satisfaction Level by Salary Level')
plt.xlabel('Salary Level')
plt.ylabel('Average Satisfaction Level')
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# # Promotion in Last Five Years

# %%
summary_stats = df['promotion_last_5years'].describe()
summary_stats
# Out:
# count    14999.000000
# mean         0.021268
# std          0.144281
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max          1.000000
# Name: promotion_last_5years, dtype: float64

# %%
print(df.corr()['promotion_last_5years'])
# Out:
# satisfaction_level       0.025605
# last_evaluation         -0.008684
# number_project          -0.006064
# average_montly_hours    -0.003544
# time_spend_company       0.067433
# Work_accident            0.039245
# left                    -0.061788
# promotion_last_5years    1.000000
# Name: promotion_last_5years, dtype: float64

# %%
promotions_last_5_years = df['promotion_last_5years'].sum()
total_employees = len(df)
percentage_promoted = (promotions_last_5_years / total_employees) * 100
print("Number of employees promoted in the last 5 years:", promotions_last_5_years)
print("Percentage of employees promoted in the last 5 years: {:.2f}%".format(percentage_promoted))
# Out:
# Number of employees promoted in the last 5 years: 319
# Percentage of employees promoted in the last 5 years: 2.13%

# %%
promotions_last_5_years = df['promotion_last_5years'].sum()
total_employees = len(df)
percentage_promoted = (promotions_last_5_years / total_employees) * 100
plt.figure(figsize=(6, 6))
plt.bar([' Not Promoted', 'Promoted'], [promotions_last_5_years, percentage_promoted], color=['brown', 'orange'])
plt.title("Promotions in the Last 5 Years")
plt.ylabel("Value")
plt.grid(axis='y', linestyle='--')
plt.show()

# %%
sns.histplot(df['promotion_last_5years'], kde=True)
plt.title('Promotions During Last 5 Years')
plt.xlabel('Promotion')
plt.ylabel('Frequency')
plt.show()

# %%
promotions_by_department = df.groupby('sales')['promotion_last_5years'].value_counts(normalize=True).unstack()
print("\nPromotion Status by Department:")
print(promotions_by_department)
# Out:
# Promotion Status by Department:
# promotion_last_5years         0         1
# sales
# IT                     0.997555  0.002445
# RandD                  0.965693  0.034307
# accounting             0.981747  0.018253
# hr                     0.979702  0.020298
# management             0.890476  0.109524
# marketing              0.949883  0.050117
# product_mng            1.000000       NaN
# sales                  0.975845  0.024155
# support                0.991027  0.008973
# technical              0.989706  0.010294

# %%
promotions_by_department = df.groupby('sales')['promotion_last_5years'].value_counts(normalize=True).unstack()
promotions_by_department.plot(kind='bar', stacked=True, colormap='Paired')
plt.title("Promotion Status by Department")
plt.xlabel("Department")
plt.ylabel("Percentage")
plt.legend(title='Promotion Status', labels=['Not Promoted', 'Promoted'])
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
promotions_by_salary = df.groupby('salary')['promotion_last_5years'].value_counts(normalize=True).unstack()
print("\nPromotion Status by Salary Level:")
print(promotions_by_salary)
# Out:
# Promotion Status by Salary Level:
# promotion_last_5years         0         1
# salary
# high                   0.941795  0.058205
# low                    0.990979  0.009021
# medium                 0.971921  0.028079

# %%
promotions_by_salary = df.groupby('salary')['promotion_last_5years'].value_counts(normalize=True).unstack()
custom_order = ['high', 'medium', 'low']
promotions_by_salary = promotions_by_salary.reindex(custom_order)
promotions_by_salary.plot(kind='bar', stacked=True, colormap='Paired', figsize=(8, 6))
plt.title("Promotion Status by Salary Level")
plt.xlabel("Salary Level")
plt.ylabel("Percentage")
plt.legend(title='Promotion Status', labels=['Not Promoted', 'Promoted'])
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
promotions_satisfied = df[df['promotion_last_5years'] == 1]['satisfaction_level'].median()
promotions_not_satisfied = df[df['promotion_last_5years'] == 0]['satisfaction_level'].median()
print("\nAverage Satisfaction Level of Promoted Employees: {:.2f}".format(promotions_satisfied))
print("Average Satisfaction Level of Non-Promoted Employees: {:.2f}".format(promotions_not_satisfied))
# Out:
# Average Satisfaction Level of Promoted Employees: 0.68
# Average Satisfaction Level of Non-Promoted Employees: 0.64

# %%
promotions_satisfied = df[df['promotion_last_5years'] == 1]['satisfaction_level'].median()
promotions_not_satisfied = df[df['promotion_last_5years'] == 0]['satisfaction_level'].median()
satisfaction_levels = [promotions_satisfied, promotions_not_satisfied]
labels = ['Promoted', 'Not Promoted']
plt.figure(figsize=(6, 6))
plt.bar(labels, satisfaction_levels, color=['red', 'green'])
plt.title("Average Satisfaction Level of Promoted vs. Non-Promoted Employees")
plt.ylabel("Average Satisfaction Level")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
time_in_company_promotion_rate = df.groupby('time_spend_company')['promotion_last_5years'].mean()
print("Promotion Rate by Time in the Company:")
print(time_in_company_promotion_rate)
# Out:
# Promotion Rate by Time in the Company:
# time_spend_company
# 2     0.016646
# 3     0.020798
# 4     0.013688
# 5     0.011541
# 6     0.023677
# 7     0.191489
# 8     0.061728
# 10    0.074766
# Name: promotion_last_5years, dtype: float64

# %%
time_in_company_promotion_rate = df.groupby('time_spend_company')['promotion_last_5years'].mean()
plt.figure(figsize=(8, 6))
ax = time_in_company_promotion_rate.plot(kind='bar', color='skyblue')
plt.title("Promotion Rate by Time in the Company")
plt.xlabel("Time in the Company (Years)")
plt.ylabel("Promotion Rate")
plt.grid(axis='y', linestyle='--')
ax.set_xticklabels(ax.get_xticklabels(), rotation=0)
plt.show()

# %%
performance_evaluation_promotion_rate = df.groupby('promotion_last_5years')['Work_accident'].mean()
print("Promotion Rate by Performance Evaluation:")
print(performance_evaluation_promotion_rate)
# Out:
# Promotion Rate by Performance Evaluation:
# promotion_last_5years
# 0    0.142575
# 1    0.238245
# Name: Work_accident, dtype: float64

# %%
performance_evaluation_promotion_rate = df.groupby('Work_accident')['promotion_last_5years'].mean()
plt.figure(figsize=(12, 6))
ss=performance_evaluation_promotion_rate.plot(kind='bar', color='skyblue')
plt.title("Promotion Rate by Performance Evaluation")
plt.xlabel("Performance Evaluation")
plt.ylabel("Promotion Rate")
plt.grid(axis='y', linestyle='--')
ss.set_xticklabels(ss.get_xticklabels(), rotation=0)
plt.show()

# %%
sns.lineplot(y=df['promotion_last_5years'],x=df['time_spend_company'], data=df)
# Out:
# <Axes: xlabel='time_spend_company', ylabel='promotion_last_5years'>

# %%
sns.lineplot(y=df['promotion_last_5years'],x=df['Work_accident'], data=df)
# Out:
# <Axes: xlabel='Work_accident', ylabel='promotion_last_5years'>

# %%
sns.lineplot(y=df['promotion_last_5years'],x=df['satisfaction_level'], data=df)
# Out:
# <Axes: xlabel='satisfaction_level', ylabel='promotion_last_5years'>

# %%
sns.lineplot(y=df['satisfaction_level'],x=df['last_evaluation'], data=df)
# Out:
# <Axes: xlabel='last_evaluation', ylabel='satisfaction_level'>

# %%
sns.lineplot(y=df['satisfaction_level'],x=df['promotion_last_5years'], data=df)
# Out:
# <Axes: xlabel='promotion_last_5years', ylabel='satisfaction_level'>
